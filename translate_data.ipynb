# %%
# !pip install deep-translator

import pandas as pd
import deep_translator
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2024.8.30)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4

# %% [markdown]
# Get the dataset from google drive link. The dataset consists of 400k+ rows and 2 columns, which is text and label.
#
# Label classes: <br>
# 0 - Sad <br>
# 1 - Happy <br>
# 2 - Neutral <br>
# 3 - Anger <br>
# 4 - Scared

# %%
import pandas as pd
url='https://drive.google.com/file/d/1roBNkutysp6l15N-brC_q7Gl8PkIRHkS/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400217 entries, 0 to 400216
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    400217 non-null  object
#  1   label   400217 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 6.1+ MB

# %% [markdown]
# Define the start of the row and the end of the row which you want to translate here!

# %%
START_ROW = 60000
END_ROW = 100000
df = df.iloc[START_ROW:END_ROW]

# %%
from deep_translator import GoogleTranslator
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

BATCH_SIZE = 10
MAX_WORKERS = 5

translator = deep_translator.GoogleTranslator(source='auto', target='id')

def safe_translate(text, translator, retries=3):
    if not text.strip():
        return ""
    for attempt in range(retries):
        try:
            return translator.translate(text)
        except Exception as e:
            if "too many requests" in str(e).lower():
                print(f"Rate limit reached. Stopping translation. Last text: {text}")
                raise RuntimeError("API rate limit exceeded.")
            elif attempt < retries - 1:
                time.sleep(2)
            else:
                print(f"Translation failed for text: {text}. Error: {e}")
                return "Translation failed"

def translate_batch(batch, indices):
    translator = GoogleTranslator(source='auto', target='id')
    return [(index, safe_translate(text, translator)) for index, text in zip(indices, batch)]

# %%
text_batches = [
    (df["text"][i:i + BATCH_SIZE].tolist(), df.index[i:i + BATCH_SIZE].tolist())
    for i in range(0, len(df), BATCH_SIZE)
]

translated_results = []

try:
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = {executor.submit(translate_batch, batch, indices): indices for batch, indices in text_batches}
        for future in as_completed(futures):
            try:
                batch_result = future.result()
                translated_results.extend(batch_result)

                # Save progress
                progress_df = pd.DataFrame(translated_results, columns=["index", "translated_text"]).set_index("index")
                progress_df = df.join(progress_df, how="left")
                progress_df.to_csv("translated_partial.csv", index=False)

                last_translated_index = progress_df.index[-1]
                print(f"Progress saved: Translated {len(translated_results)} rows from index : {START_ROW}.")
            except RuntimeError as e:
                print(f"Stopping translation due to error: {e}")
                raise
except RuntimeError:
    print("Translation process stopped due to rate limit.")
except Exception as e:
    print(f"Unexpected error occurred: {e}")

if translated_results:
    final_df = pd.DataFrame(translated_results, columns=["index", "translated_text"]).set_index("index")
    df["translated_text"] = final_df["translated_text"]
    df.to_csv("translated_final.csv", index=False)
    print("Final translation saved.")
# Out:
# Progress saved: Translated 10 rows from 60000-th row of original data.
# Progress saved: Translated 20 rows from 60000-th row of original data.
# Progress saved: Translated 30 rows from 60000-th row of original data.
# Progress saved: Translated 40 rows from 60000-th row of original data.
# Progress saved: Translated 50 rows from 60000-th row of original data.
# Progress saved: Translated 60 rows from 60000-th row of original data.
# Progress saved: Translated 70 rows from 60000-th row of original data.
# Progress saved: Translated 80 rows from 60000-th row of original data.
# Progress saved: Translated 90 rows from 60000-th row of original data.
# Progress saved: Translated 100 rows from 60000-th row of original data.
# Progress saved: Translated 110 rows from 60000-th row of original data.
# Progress saved: Translated 120 rows from 60000-th row of original data.
# Progress saved: Translated 130 rows from 60000-th row of original data.
# Progress saved: Translated 140 rows from 60000-th row of original data.
# Progress saved: Translated 150 rows from 60000-th row of original data.
# Progress saved: Translated 160 rows from 60000-th row of original data.
# Progress saved: Translated 170 rows from 60000-th row of original data.
# Progress saved: Translated 180 rows from 60000-th row of original data.
# Progress saved: Translated 190 rows from 60000-th row of original data.
# Progress saved: Translated 200 rows from 60000-th row of original data.
# Progress saved: Translated 210 rows from 60000-th row of original data.
# Progress saved: Translated 220 rows from 60000-th row of original data.
# Progress saved: Translated 230 rows from 60000-th row of original data.
# Progress saved: Translated 240 rows from 60000-th row of original data.
# Progress saved: Translated 250 rows from 60000-th row of original data.
# Progress saved: Translated 260 rows from 60000-th row of original data.
# Progress saved: Translated 270 rows from 60000-th row of original data.
# Progress saved: Translated 280 rows from 60000-th row of original data.
# Progress saved: Translated 290 rows from 60000-th row of original data.
# Progress saved: Translated 300 rows from 60000-th row of original data.
# Progress saved: Translated 310 rows from 60000-th row of original data.
# Progress saved: Translated 320 rows from 60000-th row of original data.
# Progress saved: Translated 330 rows from 60000-th row of original data.
# Progress saved: Translated 340 rows from 60000-th row of original data.
# Progress saved: Translated 350 rows from 60000-th row of original data.
# Progress saved: Translated 360 rows from 60000-th row of original data.
# Progress saved: Translated 370 rows from 60000-th row of original data.
# Progress saved: Translated 380 rows from 60000-th row of original data.
# Progress saved: Translated 390 rows from 60000-th row of original data.
# Progress saved: Translated 400 rows from 60000-th row of original data.
# Progress saved: Translated 410 rows from 60000-th row of original data.
# Progress saved: Translated 420 rows from 60000-th row of original data.
# Progress saved: Translated 430 rows from 60000-th row of original data.
# Progress saved: Translated 440 rows from 60000-th row of original data.
# Progress saved: Translated 450 rows from 60000-th row of original data.
# Progress saved: Translated 460 rows from 60000-th row of original data.
# Progress saved: Translated 470 rows from 60000-th row of original data.
# Progress saved: Translated 480 rows from 60000-th row of original data.
# Progress saved: Translated 490 rows from 60000-th row of original data.
# Progress saved: Translated 500 rows from 60000-th row of original data.
# Progress saved: Translated 510 rows from 60000-th row of original data.
# Progress saved: Translated 520 rows from 60000-th row of original data.
# Progress saved: Translated 530 rows from 60000-th row of original data.
# Progress saved: Translated 540 rows from 60000-th row of original data.
# Progress saved: Translated 550 rows from 60000-th row of original data.
# Progress saved: Translated 560 rows from 60000-th row of original data.
# Progress saved: Translated 570 rows from 60000-th row of original data.
# Progress saved: Translated 580 rows from 60000-th row of original data.
# Progress saved: Translated 590 rows from 60000-th row of original data.
# Progress saved: Translated 600 rows from 60000-th row of original data.
# Progress saved: Translated 610 rows from 60000-th row of original data.
# Progress saved: Translated 620 rows from 60000-th row of original data.
# Progress saved: Translated 630 rows from 60000-th row of original data.
# Progress saved: Translated 640 rows from 60000-th row of original data.
# Progress saved: Translated 650 rows from 60000-th row of original data.
# Progress saved: Translated 660 rows from 60000-th row of original data.
# Progress saved: Translated 670 rows from 60000-th row of original data.
# Progress saved: Translated 680 rows from 60000-th row of original data.
# Progress saved: Translated 690 rows from 60000-th row of original data.
# Progress saved: Translated 700 rows from 60000-th row of original data.
# Progress saved: Translated 710 rows from 60000-th row of original data.
# Progress saved: Translated 720 rows from 60000-th row of original data.
# Progress saved: Translated 730 rows from 60000-th row of original data.
# Progress saved: Translated 740 rows from 60000-th row of original data.
# Progress saved: Translated 750 rows from 60000-th row of original data.
# Progress saved: Translated 760 rows from 60000-th row of original data.
# Progress saved: Translated 770 rows from 60000-th row of original data.
# Progress saved: Translated 780 rows from 60000-th row of original data.
# Progress saved: Translated 790 rows from 60000-th row of original data.
# Progress saved: Translated 800 rows from 60000-th row of original data.
# Progress saved: Translated 810 rows from 60000-th row of original data.
# Progress saved: Translated 820 rows from 60000-th row of original data.
# Progress saved: Translated 830 rows from 60000-th row of original data.
# Progress saved: Translated 840 rows from 60000-th row of original data.
# Progress saved: Translated 850 rows from 60000-th row of original data.
# Progress saved: Translated 860 rows from 60000-th row of original data.
# Progress saved: Translated 870 rows from 60000-th row of original data.
# Progress saved: Translated 880 rows from 60000-th row of original data.
# Progress saved: Translated 890 rows from 60000-th row of original data.
# Progress saved: Translated 900 rows from 60000-th row of original data.
# Progress saved: Translated 910 rows from 60000-th row of original data.
# Progress saved: Translated 920 rows from 60000-th row of original data.
# Progress saved: Translated 930 rows from 60000-th row of original data.
# Progress saved: Translated 940 rows from 60000-th row of original data.
# Progress saved: Translated 950 rows from 60000-th row of original data.
# Progress saved: Translated 960 rows from 60000-th row of original data.
# Progress saved: Translated 970 rows from 60000-th row of original data.
# Progress saved: Translated 980 rows from 60000-th row of original data.
# Progress saved: Translated 990 rows from 60000-th row of original data.
# Progress saved: Translated 1000 rows from 60000-th row of original data.
# Progress saved: Translated 1010 rows from 60000-th row of original data.
# Progress saved: Translated 1020 rows from 60000-th row of original data.
# Progress saved: Translated 1030 rows from 60000-th row of original data.
# Progress saved: Translated 1040 rows from 60000-th row of original data.
# Progress saved: Translated 1050 rows from 60000-th row of original data.
# Progress saved: Translated 1060 rows from 60000-th row of original data.
# Progress saved: Translated 1070 rows from 60000-th row of original data.
# Progress saved: Translated 1080 rows from 60000-th row of original data.
# Progress saved: Translated 1090 rows from 60000-th row of original data.
# Progress saved: Translated 1100 rows from 60000-th row of original data.
# Progress saved: Translated 1110 rows from 60000-th row of original data.
# Progress saved: Translated 1120 rows from 60000-th row of original data.
# Progress saved: Translated 1130 rows from 60000-th row of original data.
# Progress saved: Translated 1140 rows from 60000-th row of original data.
# Progress saved: Translated 1150 rows from 60000-th row of original data.
# Progress saved: Translated 1160 rows from 60000-th row of original data.
# Progress saved: Translated 1170 rows from 60000-th row of original data.
# Progress saved: Translated 1180 rows from 60000-th row of original data.
# Progress saved: Translated 1190 rows from 60000-th row of original data.
# Progress saved: Translated 1200 rows from 60000-th row of original data.
# Progress saved: Translated 1210 rows from 60000-th row of original data.
# Progress saved: Translated 1220 rows from 60000-th row of original data.
# Progress saved: Translated 1230 rows from 60000-th row of original data.
# Progress saved: Translated 1240 rows from 60000-th row of original data.
# Progress saved: Translated 1250 rows from 60000-th row of original data.
# Progress saved: Translated 1260 rows from 60000-th row of original data.
# Progress saved: Translated 1270 rows from 60000-th row of original data.
# Progress saved: Translated 1280 rows from 60000-th row of original data.
# Progress saved: Translated 1290 rows from 60000-th row of original data.
# Progress saved: Translated 1300 rows from 60000-th row of original data.
# Progress saved: Translated 1310 rows from 60000-th row of original data.
# Progress saved: Translated 1320 rows from 60000-th row of original data.
# Progress saved: Translated 1330 rows from 60000-th row of original data.
# Progress saved: Translated 1340 rows from 60000-th row of original data.
# Progress saved: Translated 1350 rows from 60000-th row of original data.
# Progress saved: Translated 1360 rows from 60000-th row of original data.
# Progress saved: Translated 1370 rows from 60000-th row of original data.
# Progress saved: Translated 1380 rows from 60000-th row of original data.
# Progress saved: Translated 1390 rows from 60000-th row of original data.
# Progress saved: Translated 1400 rows from 60000-th row of original data.
# Progress saved: Translated 1410 rows from 60000-th row of original data.
# Progress saved: Translated 1420 rows from 60000-th row of original data.
# Progress saved: Translated 1430 rows from 60000-th row of original data.
# Progress saved: Translated 1440 rows from 60000-th row of original data.
# Progress saved: Translated 1450 rows from 60000-th row of original data.
# Progress saved: Translated 1460 rows from 60000-th row of original data.
# Progress saved: Translated 1470 rows from 60000-th row of original data.
# Progress saved: Translated 1480 rows from 60000-th row of original data.
# Progress saved: Translated 1490 rows from 60000-th row of original data.
# Progress saved: Translated 1500 rows from 60000-th row of original data.
# Progress saved: Translated 1510 rows from 60000-th row of original data.
# Progress saved: Translated 1520 rows from 60000-th row of original data.
# Progress saved: Translated 1530 rows from 60000-th row of original data.
# Progress saved: Translated 1540 rows from 60000-th row of original data.
# Progress saved: Translated 1550 rows from 60000-th row of original data.
# Progress saved: Translated 1560 rows from 60000-th row of original data.
# Progress saved: Translated 1570 rows from 60000-th row of original data.
# Progress saved: Translated 1580 rows from 60000-th row of original data.
# Progress saved: Translated 1590 rows from 60000-th row of original data.
# Progress saved: Translated 1600 rows from 60000-th row of original data.
# Progress saved: Translated 1610 rows from 60000-th row of original data.
# Progress saved: Translated 1620 rows from 60000-th row of original data.
# Progress saved: Translated 1630 rows from 60000-th row of original data.
# Progress saved: Translated 1640 rows from 60000-th row of original data.
# Progress saved: Translated 1650 rows from 60000-th row of original data.
# Progress saved: Translated 1660 rows from 60000-th row of original data.
# Progress saved: Translated 1670 rows from 60000-th row of original data.
# Progress saved: Translated 1680 rows from 60000-th row of original data.
# Progress saved: Translated 1690 rows from 60000-th row of original data.
# Progress saved: Translated 1700 rows from 60000-th row of original data.
# Progress saved: Translated 1710 rows from 60000-th row of original data.
# Progress saved: Translated 1720 rows from 60000-th row of original data.
# Progress saved: Translated 1730 rows from 60000-th row of original data.
# Progress saved: Translated 1740 rows from 60000-th row of original data.
# Progress saved: Translated 1750 rows from 60000-th row of original data.
# Progress saved: Translated 1760 rows from 60000-th row of original data.
# Progress saved: Translated 1770 rows from 60000-th row of original data.
# Progress saved: Translated 1780 rows from 60000-th row of original data.
# Progress saved: Translated 1790 rows from 60000-th row of original data.
# Progress saved: Translated 1800 rows from 60000-th row of original data.
# Progress saved: Translated 1810 rows from 60000-th row of original data.
# Progress saved: Translated 1820 rows from 60000-th row of original data.
# Progress saved: Translated 1830 rows from 60000-th row of original data.
# Progress saved: Translated 1840 rows from 60000-th row of original data.
# Progress saved: Translated 1850 rows from 60000-th row of original data.
# Progress saved: Translated 1860 rows from 60000-th row of original data.
# Progress saved: Translated 1870 rows from 60000-th row of original data.
# Progress saved: Translated 1880 rows from 60000-th row of original data.
# Progress saved: Translated 1890 rows from 60000-th row of original data.
# Progress saved: Translated 1900 rows from 60000-th row of original data.
# Progress saved: Translated 1910 rows from 60000-th row of original data.
# Progress saved: Translated 1920 rows from 60000-th row of original data.
# Progress saved: Translated 1930 rows from 60000-th row of original data.
# Progress saved: Translated 1940 rows from 60000-th row of original data.
# Progress saved: Translated 1950 rows from 60000-th row of original data.
# Progress saved: Translated 1960 rows from 60000-th row of original data.
# Progress saved: Translated 1970 rows from 60000-th row of original data.
# Progress saved: Translated 1980 rows from 60000-th row of original data.
# Progress saved: Translated 1990 rows from 60000-th row of original data.
# Progress saved: Translated 2000 rows from 60000-th row of original data.
# Progress saved: Translated 2010 rows from 60000-th row of original data.
# Progress saved: Translated 2020 rows from 60000-th row of original data.
# Progress saved: Translated 2030 rows from 60000-th row of original data.
# Progress saved: Translated 2040 rows from 60000-th row of original data.
# Progress saved: Translated 2050 rows from 60000-th row of original data.
# Progress saved: Translated 2060 rows from 60000-th row of original data.
# Progress saved: Translated 2070 rows from 60000-th row of original data.
# Progress saved: Translated 2080 rows from 60000-th row of original data.
# Progress saved: Translated 2090 rows from 60000-th row of original data.
# Progress saved: Translated 2100 rows from 60000-th row of original data.
# Progress saved: Translated 2110 rows from 60000-th row of original data.
# Progress saved: Translated 2120 rows from 60000-th row of original data.
# Progress saved: Translated 2130 rows from 60000-th row of original data.
# Progress saved: Translated 2140 rows from 60000-th row of original data.
# Progress saved: Translated 2150 rows from 60000-th row of original data.
# Progress saved: Translated 2160 rows from 60000-th row of original data.
# Progress saved: Translated 2170 rows from 60000-th row of original data.
# Progress saved: Translated 2180 rows from 60000-th row of original data.
# Progress saved: Translated 2190 rows from 60000-th row of original data.
# Progress saved: Translated 2200 rows from 60000-th row of original data.
# Progress saved: Translated 2210 rows from 60000-th row of original data.
# Progress saved: Translated 2220 rows from 60000-th row of original data.
# Progress saved: Translated 2230 rows from 60000-th row of original data.
# Progress saved: Translated 2240 rows from 60000-th row of original data.
# Progress saved: Translated 2250 rows from 60000-th row of original data.
# Progress saved: Translated 2260 rows from 60000-th row of original data.
# Progress saved: Translated 2270 rows from 60000-th row of original data.
# Progress saved: Translated 2280 rows from 60000-th row of original data.
# Progress saved: Translated 2290 rows from 60000-th row of original data.
# Progress saved: Translated 2300 rows from 60000-th row of original data.
# Progress saved: Translated 2310 rows from 60000-th row of original data.
# Progress saved: Translated 2320 rows from 60000-th row of original data.
# Progress saved: Translated 2330 rows from 60000-th row of original data.
# Progress saved: Translated 2340 rows from 60000-th row of original data.
# Progress saved: Translated 2350 rows from 60000-th row of original data.
# Progress saved: Translated 2360 rows from 60000-th row of original data.
# Progress saved: Translated 2370 rows from 60000-th row of original data.
# Progress saved: Translated 2380 rows from 60000-th row of original data.
# Progress saved: Translated 2390 rows from 60000-th row of original data.
# Progress saved: Translated 2400 rows from 60000-th row of original data.
# Progress saved: Translated 2410 rows from 60000-th row of original data.
# Progress saved: Translated 2420 rows from 60000-th row of original data.
# Progress saved: Translated 2430 rows from 60000-th row of original data.
# Progress saved: Translated 2440 rows from 60000-th row of original data.
# Progress saved: Translated 2450 rows from 60000-th row of original data.
# Progress saved: Translated 2460 rows from 60000-th row of original data.
# Progress saved: Translated 2470 rows from 60000-th row of original data.
# Progress saved: Translated 2480 rows from 60000-th row of original data.
# Progress saved: Translated 2490 rows from 60000-th row of original data.
# Progress saved: Translated 2500 rows from 60000-th row of original data.
# Progress saved: Translated 2510 rows from 60000-th row of original data.
# Progress saved: Translated 2520 rows from 60000-th row of original data.
# Progress saved: Translated 2530 rows from 60000-th row of original data.
# Progress saved: Translated 2540 rows from 60000-th row of original data.
# Progress saved: Translated 2550 rows from 60000-th row of original data.
# Progress saved: Translated 2560 rows from 60000-th row of original data.
# Progress saved: Translated 2570 rows from 60000-th row of original data.
# Progress saved: Translated 2580 rows from 60000-th row of original data.
# Progress saved: Translated 2590 rows from 60000-th row of original data.
# Progress saved: Translated 2600 rows from 60000-th row of original data.
# Progress saved: Translated 2610 rows from 60000-th row of original data.
# Progress saved: Translated 2620 rows from 60000-th row of original data.
# Progress saved: Translated 2630 rows from 60000-th row of original data.
# Progress saved: Translated 2640 rows from 60000-th row of original data.
# Progress saved: Translated 2650 rows from 60000-th row of original data.
# Progress saved: Translated 2660 rows from 60000-th row of original data.
# Progress saved: Translated 2670 rows from 60000-th row of original data.
# Progress saved: Translated 2680 rows from 60000-th row of original data.
# Progress saved: Translated 2690 rows from 60000-th row of original data.
# Progress saved: Translated 2700 rows from 60000-th row of original data.
# Progress saved: Translated 2710 rows from 60000-th row of original data.
# Progress saved: Translated 2720 rows from 60000-th row of original data.
# Progress saved: Translated 2730 rows from 60000-th row of original data.
# Progress saved: Translated 2740 rows from 60000-th row of original data.
# Progress saved: Translated 2750 rows from 60000-th row of original data.
# Progress saved: Translated 2760 rows from 60000-th row of original data.
# Progress saved: Translated 2770 rows from 60000-th row of original data.
# Progress saved: Translated 2780 rows from 60000-th row of original data.
# Progress saved: Translated 2790 rows from 60000-th row of original data.
# Progress saved: Translated 2800 rows from 60000-th row of original data.
# Progress saved: Translated 2810 rows from 60000-th row of original data.
# Progress saved: Translated 2820 rows from 60000-th row of original data.
# Progress saved: Translated 2830 rows from 60000-th row of original data.
# Progress saved: Translated 2840 rows from 60000-th row of original data.
# Progress saved: Translated 2850 rows from 60000-th row of original data.
# Progress saved: Translated 2860 rows from 60000-th row of original data.
# Progress saved: Translated 2870 rows from 60000-th row of original data.
# Progress saved: Translated 2880 rows from 60000-th row of original data.
# Progress saved: Translated 2890 rows from 60000-th row of original data.
# Progress saved: Translated 2900 rows from 60000-th row of original data.
# Progress saved: Translated 2910 rows from 60000-th row of original data.
# Progress saved: Translated 2920 rows from 60000-th row of original data.
# Progress saved: Translated 2930 rows from 60000-th row of original data.
# Progress saved: Translated 2940 rows from 60000-th row of original data.
# Progress saved: Translated 2950 rows from 60000-th row of original data.
# Progress saved: Translated 2960 rows from 60000-th row of original data.
# Progress saved: Translated 2970 rows from 60000-th row of original data.
# Progress saved: Translated 2980 rows from 60000-th row of original data.
# Progress saved: Translated 2990 rows from 60000-th row of original data.
# Progress saved: Translated 3000 rows from 60000-th row of original data.
# Progress saved: Translated 3010 rows from 60000-th row of original data.
# Progress saved: Translated 3020 rows from 60000-th row of original data.
# Progress saved: Translated 3030 rows from 60000-th row of original data.
# Progress saved: Translated 3040 rows from 60000-th row of original data.
# Progress saved: Translated 3050 rows from 60000-th row of original data.
# Progress saved: Translated 3060 rows from 60000-th row of original data.
# Progress saved: Translated 3070 rows from 60000-th row of original data.
# Progress saved: Translated 3080 rows from 60000-th row of original data.
# Progress saved: Translated 3090 rows from 60000-th row of original data.
# Progress saved: Translated 3100 rows from 60000-th row of original data.
# Progress saved: Translated 3110 rows from 60000-th row of original data.
# Progress saved: Translated 3120 rows from 60000-th row of original data.
# Progress saved: Translated 3130 rows from 60000-th row of original data.
# Progress saved: Translated 3140 rows from 60000-th row of original data.
# Progress saved: Translated 3150 rows from 60000-th row of original data.
# Progress saved: Translated 3160 rows from 60000-th row of original data.
# Progress saved: Translated 3170 rows from 60000-th row of original data.
# Progress saved: Translated 3180 rows from 60000-th row of original data.
# Progress saved: Translated 3190 rows from 60000-th row of original data.
# Progress saved: Translated 3200 rows from 60000-th row of original data.
# Progress saved: Translated 3210 rows from 60000-th row of original data.
# Progress saved: Translated 3220 rows from 60000-th row of original data.
# Progress saved: Translated 3230 rows from 60000-th row of original data.
# Progress saved: Translated 3240 rows from 60000-th row of original data.
# Progress saved: Translated 3250 rows from 60000-th row of original data.
# Progress saved: Translated 3260 rows from 60000-th row of original data.
# Progress saved: Translated 3270 rows from 60000-th row of original data.
# Progress saved: Translated 3280 rows from 60000-th row of original data.
# Progress saved: Translated 3290 rows from 60000-th row of original data.
# Progress saved: Translated 3300 rows from 60000-th row of original data.
# Progress saved: Translated 3310 rows from 60000-th row of original data.
# Progress saved: Translated 3320 rows from 60000-th row of original data.
# Progress saved: Translated 3330 rows from 60000-th row of original data.
# Progress saved: Translated 3340 rows from 60000-th row of original data.
# Progress saved: Translated 3350 rows from 60000-th row of original data.
# Progress saved: Translated 3360 rows from 60000-th row of original data.
# Progress saved: Translated 3370 rows from 60000-th row of original data.
# Progress saved: Translated 3380 rows from 60000-th row of original data.
# Progress saved: Translated 3390 rows from 60000-th row of original data.
# Progress saved: Translated 3400 rows from 60000-th row of original data.
# Progress saved: Translated 3410 rows from 60000-th row of original data.
# Progress saved: Translated 3420 rows from 60000-th row of original data.
# Progress saved: Translated 3430 rows from 60000-th row of original data.
# Progress saved: Translated 3440 rows from 60000-th row of original data.
# Progress saved: Translated 3450 rows from 60000-th row of original data.
# Progress saved: Translated 3460 rows from 60000-th row of original data.
# Progress saved: Translated 3470 rows from 60000-th row of original data.
# Progress saved: Translated 3480 rows from 60000-th row of original data.
# Progress saved: Translated 3490 rows from 60000-th row of original data.
# Progress saved: Translated 3500 rows from 60000-th row of original data.
# Progress saved: Translated 3510 rows from 60000-th row of original data.
# Progress saved: Translated 3520 rows from 60000-th row of original data.
# Progress saved: Translated 3530 rows from 60000-th row of original data.
# Progress saved: Translated 3540 rows from 60000-th row of original data.
# Progress saved: Translated 3550 rows from 60000-th row of original data.
# Progress saved: Translated 3560 rows from 60000-th row of original data.
# Progress saved: Translated 3570 rows from 60000-th row of original data.
# Progress saved: Translated 3580 rows from 60000-th row of original data.
# Progress saved: Translated 3590 rows from 60000-th row of original data.
# Progress saved: Translated 3600 rows from 60000-th row of original data.
# Progress saved: Translated 3610 rows from 60000-th row of original data.
# Progress saved: Translated 3620 rows from 60000-th row of original data.
# Progress saved: Translated 3630 rows from 60000-th row of original data.
# Progress saved: Translated 3640 rows from 60000-th row of original data.
# Progress saved: Translated 3650 rows from 60000-th row of original data.
# Progress saved: Translated 3660 rows from 60000-th row of original data.
# Progress saved: Translated 3670 rows from 60000-th row of original data.
# Progress saved: Translated 3680 rows from 60000-th row of original data.
# Progress saved: Translated 3690 rows from 60000-th row of original data.
# Progress saved: Translated 3700 rows from 60000-th row of original data.
# Progress saved: Translated 3710 rows from 60000-th row of original data.
# Progress saved: Translated 3720 rows from 60000-th row of original data.
# Progress saved: Translated 3730 rows from 60000-th row of original data.
# Progress saved: Translated 3740 rows from 60000-th row of original data.
# Progress saved: Translated 3750 rows from 60000-th row of original data.
# Progress saved: Translated 3760 rows from 60000-th row of original data.
# Progress saved: Translated 3770 rows from 60000-th row of original data.
# Progress saved: Translated 3780 rows from 60000-th row of original data.
# Progress saved: Translated 3790 rows from 60000-th row of original data.
# Progress saved: Translated 3800 rows from 60000-th row of original data.
# Progress saved: Translated 3810 rows from 60000-th row of original data.
# Progress saved: Translated 3820 rows from 60000-th row of original data.
# Progress saved: Translated 3830 rows from 60000-th row of original data.
# Progress saved: Translated 3840 rows from 60000-th row of original data.
# Progress saved: Translated 3850 rows from 60000-th row of original data.
# Progress saved: Translated 3860 rows from 60000-th row of original data.
# Progress saved: Translated 3870 rows from 60000-th row of original data.
# Progress saved: Translated 3880 rows from 60000-th row of original data.
# Progress saved: Translated 3890 rows from 60000-th row of original data.
# Progress saved: Translated 3900 rows from 60000-th row of original data.
# Progress saved: Translated 3910 rows from 60000-th row of original data.
# Progress saved: Translated 3920 rows from 60000-th row of original data.
# Progress saved: Translated 3930 rows from 60000-th row of original data.
# Progress saved: Translated 3940 rows from 60000-th row of original data.
# Progress saved: Translated 3950 rows from 60000-th row of original data.
# Progress saved: Translated 3960 rows from 60000-th row of original data.
# Progress saved: Translated 3970 rows from 60000-th row of original data.
# Progress saved: Translated 3980 rows from 60000-th row of original data.
# Progress saved: Translated 3990 rows from 60000-th row of original data.
# Progress saved: Translated 4000 rows from 60000-th row of original data.
# Progress saved: Translated 4010 rows from 60000-th row of original data.
# Progress saved: Translated 4020 rows from 60000-th row of original data.
# Progress saved: Translated 4030 rows from 60000-th row of original data.
# Progress saved: Translated 4040 rows from 60000-th row of original data.
# Progress saved: Translated 4050 rows from 60000-th row of original data.
# Progress saved: Translated 4060 rows from 60000-th row of original data.
# Progress saved: Translated 4070 rows from 60000-th row of original data.
# Progress saved: Translated 4080 rows from 60000-th row of original data.
# Progress saved: Translated 4090 rows from 60000-th row of original data.
# Progress saved: Translated 4100 rows from 60000-th row of original data.
# Progress saved: Translated 4110 rows from 60000-th row of original data.
# Progress saved: Translated 4120 rows from 60000-th row of original data.
# Progress saved: Translated 4130 rows from 60000-th row of original data.
# Progress saved: Translated 4140 rows from 60000-th row of original data.
# Progress saved: Translated 4150 rows from 60000-th row of original data.
# Progress saved: Translated 4160 rows from 60000-th row of original data.
# Progress saved: Translated 4170 rows from 60000-th row of original data.
# Progress saved: Translated 4180 rows from 60000-th row of original data.
# Progress saved: Translated 4190 rows from 60000-th row of original data.
# Progress saved: Translated 4200 rows from 60000-th row of original data.
# Progress saved: Translated 4210 rows from 60000-th row of original data.
# Progress saved: Translated 4220 rows from 60000-th row of original data.
# Progress saved: Translated 4230 rows from 60000-th row of original data.
# Progress saved: Translated 4240 rows from 60000-th row of original data.
# Progress saved: Translated 4250 rows from 60000-th row of original data.
# Progress saved: Translated 4260 rows from 60000-th row of original data.
# Progress saved: Translated 4270 rows from 60000-th row of original data.
# Progress saved: Translated 4280 rows from 60000-th row of original data.
# Progress saved: Translated 4290 rows from 60000-th row of original data.
# Progress saved: Translated 4300 rows from 60000-th row of original data.
# Progress saved: Translated 4310 rows from 60000-th row of original data.
# Progress saved: Translated 4320 rows from 60000-th row of original data.
# Progress saved: Translated 4330 rows from 60000-th row of original data.
# Progress saved: Translated 4340 rows from 60000-th row of original data.
# Progress saved: Translated 4350 rows from 60000-th row of original data.
# Progress saved: Translated 4360 rows from 60000-th row of original data.
# Progress saved: Translated 4370 rows from 60000-th row of original data.
# Progress saved: Translated 4380 rows from 60000-th row of original data.
# Progress saved: Translated 4390 rows from 60000-th row of original data.
# Progress saved: Translated 4400 rows from 60000-th row of original data.
# Progress saved: Translated 4410 rows from 60000-th row of original data.
# Progress saved: Translated 4420 rows from 60000-th row of original data.
# Progress saved: Translated 4430 rows from 60000-th row of original data.
# Progress saved: Translated 4440 rows from 60000-th row of original data.
# Progress saved: Translated 4450 rows from 60000-th row of original data.
# Progress saved: Translated 4460 rows from 60000-th row of original data.
# Progress saved: Translated 4470 rows from 60000-th row of original data.
# Progress saved: Translated 4480 rows from 60000-th row of original data.
# Progress saved: Translated 4490 rows from 60000-th row of original data.
# Progress saved: Translated 4500 rows from 60000-th row of original data.
# Progress saved: Translated 4510 rows from 60000-th row of original data.
# Progress saved: Translated 4520 rows from 60000-th row of original data.
# Progress saved: Translated 4530 rows from 60000-th row of original data.
# Progress saved: Translated 4540 rows from 60000-th row of original data.
# Progress saved: Translated 4550 rows from 60000-th row of original data.
# Progress saved: Translated 4560 rows from 60000-th row of original data.
# Progress saved: Translated 4570 rows from 60000-th row of original data.
# Progress saved: Translated 4580 rows from 60000-th row of original data.
# Progress saved: Translated 4590 rows from 60000-th row of original data.
# Progress saved: Translated 4600 rows from 60000-th row of original data.
# Progress saved: Translated 4610 rows from 60000-th row of original data.
# Progress saved: Translated 4620 rows from 60000-th row of original data.
# Progress saved: Translated 4630 rows from 60000-th row of original data.
# Progress saved: Translated 4640 rows from 60000-th row of original data.
# Progress saved: Translated 4650 rows from 60000-th row of original data.
# Progress saved: Translated 4660 rows from 60000-th row of original data.
# Progress saved: Translated 4670 rows from 60000-th row of original data.
# Progress saved: Translated 4680 rows from 60000-th row of original data.
# Progress saved: Translated 4690 rows from 60000-th row of original data.
# Progress saved: Translated 4700 rows from 60000-th row of original data.
# Progress saved: Translated 4710 rows from 60000-th row of original data.
# Progress saved: Translated 4720 rows from 60000-th row of original data.
# Progress saved: Translated 4730 rows from 60000-th row of original data.
# Progress saved: Translated 4740 rows from 60000-th row of original data.
# Progress saved: Translated 4750 rows from 60000-th row of original data.
# Progress saved: Translated 4760 rows from 60000-th row of original data.
# Progress saved: Translated 4770 rows from 60000-th row of original data.
# Progress saved: Translated 4780 rows from 60000-th row of original data.
# Progress saved: Translated 4790 rows from 60000-th row of original data.
# Progress saved: Translated 4800 rows from 60000-th row of original data.
# Progress saved: Translated 4810 rows from 60000-th row of original data.
# Progress saved: Translated 4820 rows from 60000-th row of original data.
# Progress saved: Translated 4830 rows from 60000-th row of original data.
# Progress saved: Translated 4840 rows from 60000-th row of original data.
# Progress saved: Translated 4850 rows from 60000-th row of original data.
# Progress saved: Translated 4860 rows from 60000-th row of original data.
# Progress saved: Translated 4870 rows from 60000-th row of original data.
# Progress saved: Translated 4880 rows from 60000-th row of original data.
# Progress saved: Translated 4890 rows from 60000-th row of original data.
# Progress saved: Translated 4900 rows from 60000-th row of original data.
# Progress saved: Translated 4910 rows from 60000-th row of original data.
# Progress saved: Translated 4920 rows from 60000-th row of original data.
# Progress saved: Translated 4930 rows from 60000-th row of original data.
# Progress saved: Translated 4940 rows from 60000-th row of original data.
# Progress saved: Translated 4950 rows from 60000-th row of original data.
# Progress saved: Translated 4960 rows from 60000-th row of original data.
# Progress saved: Translated 4970 rows from 60000-th row of original data.
# Progress saved: Translated 4980 rows from 60000-th row of original data.
# Progress saved: Translated 4990 rows from 60000-th row of original data.
# Progress saved: Translated 5000 rows from 60000-th row of original data.
# Progress saved: Translated 5010 rows from 60000-th row of original data.
# Progress saved: Translated 5020 rows from 60000-th row of original data.
# Progress saved: Translated 5030 rows from 60000-th row of original data.
# Progress saved: Translated 5040 rows from 60000-th row of original data.
# Progress saved: Translated 5050 rows from 60000-th row of original data.
# Progress saved: Translated 5060 rows from 60000-th row of original data.
# Progress saved: Translated 5070 rows from 60000-th row of original data.
# Progress saved: Translated 5080 rows from 60000-th row of original data.
# Progress saved: Translated 5090 rows from 60000-th row of original data.
# Progress saved: Translated 5100 rows from 60000-th row of original data.
# Progress saved: Translated 5110 rows from 60000-th row of original data.
# Progress saved: Translated 5120 rows from 60000-th row of original data.
# Progress saved: Translated 5130 rows from 60000-th row of original data.
# Progress saved: Translated 5140 rows from 60000-th row of original data.
# Progress saved: Translated 5150 rows from 60000-th row of original data.
# Progress saved: Translated 5160 rows from 60000-th row of original data.
# Progress saved: Translated 5170 rows from 60000-th row of original data.
# Progress saved: Translated 5180 rows from 60000-th row of original data.
# Progress saved: Translated 5190 rows from 60000-th row of original data.
# Progress saved: Translated 5200 rows from 60000-th row of original data.
# Progress saved: Translated 5210 rows from 60000-th row of original data.
# Progress saved: Translated 5220 rows from 60000-th row of original data.
# Progress saved: Translated 5230 rows from 60000-th row of original data.
# Progress saved: Translated 5240 rows from 60000-th row of original data.
# Progress saved: Translated 5250 rows from 60000-th row of original data.
# Progress saved: Translated 5260 rows from 60000-th row of original data.
# Progress saved: Translated 5270 rows from 60000-th row of original data.
# Progress saved: Translated 5280 rows from 60000-th row of original data.
# Progress saved: Translated 5290 rows from 60000-th row of original data.
# Progress saved: Translated 5300 rows from 60000-th row of original data.
# Progress saved: Translated 5310 rows from 60000-th row of original data.
# Progress saved: Translated 5320 rows from 60000-th row of original data.
# Progress saved: Translated 5330 rows from 60000-th row of original data.
# Progress saved: Translated 5340 rows from 60000-th row of original data.
# Progress saved: Translated 5350 rows from 60000-th row of original data.
# Progress saved: Translated 5360 rows from 60000-th row of original data.
# Progress saved: Translated 5370 rows from 60000-th row of original data.
# Progress saved: Translated 5380 rows from 60000-th row of original data.
# Progress saved: Translated 5390 rows from 60000-th row of original data.
# Progress saved: Translated 5400 rows from 60000-th row of original data.
# Progress saved: Translated 5410 rows from 60000-th row of original data.
# Progress saved: Translated 5420 rows from 60000-th row of original data.
# Progress saved: Translated 5430 rows from 60000-th row of original data.
# Progress saved: Translated 5440 rows from 60000-th row of original data.
# Progress saved: Translated 5450 rows from 60000-th row of original data.
# Progress saved: Translated 5460 rows from 60000-th row of original data.
# Progress saved: Translated 5470 rows from 60000-th row of original data.
# Progress saved: Translated 5480 rows from 60000-th row of original data.
# Progress saved: Translated 5490 rows from 60000-th row of original data.
# Progress saved: Translated 5500 rows from 60000-th row of original data.
# Progress saved: Translated 5510 rows from 60000-th row of original data.
# Progress saved: Translated 5520 rows from 60000-th row of original data.
# Progress saved: Translated 5530 rows from 60000-th row of original data.
# Progress saved: Translated 5540 rows from 60000-th row of original data.
# Progress saved: Translated 5550 rows from 60000-th row of original data.
# Progress saved: Translated 5560 rows from 60000-th row of original data.
# Progress saved: Translated 5570 rows from 60000-th row of original data.
# Progress saved: Translated 5580 rows from 60000-th row of original data.
# Progress saved: Translated 5590 rows from 60000-th row of original data.
# Progress saved: Translated 5600 rows from 60000-th row of original data.
# Progress saved: Translated 5610 rows from 60000-th row of original data.
# Progress saved: Translated 5620 rows from 60000-th row of original data.
# Progress saved: Translated 5630 rows from 60000-th row of original data.
# Progress saved: Translated 5640 rows from 60000-th row of original data.
# Progress saved: Translated 5650 rows from 60000-th row of original data.
# Progress saved: Translated 5660 rows from 60000-th row of original data.
# Progress saved: Translated 5670 rows from 60000-th row of original data.
# Progress saved: Translated 5680 rows from 60000-th row of original data.
# Progress saved: Translated 5690 rows from 60000-th row of original data.
# Progress saved: Translated 5700 rows from 60000-th row of original data.
# Progress saved: Translated 5710 rows from 60000-th row of original data.
# Progress saved: Translated 5720 rows from 60000-th row of original data.
# Progress saved: Translated 5730 rows from 60000-th row of original data.
# Progress saved: Translated 5740 rows from 60000-th row of original data.
# Progress saved: Translated 5750 rows from 60000-th row of original data.
# Progress saved: Translated 5760 rows from 60000-th row of original data.
# Progress saved: Translated 5770 rows from 60000-th row of original data.
# Progress saved: Translated 5780 rows from 60000-th row of original data.
# Progress saved: Translated 5790 rows from 60000-th row of original data.
# Progress saved: Translated 5800 rows from 60000-th row of original data.
# Progress saved: Translated 5810 rows from 60000-th row of original data.
# Progress saved: Translated 5820 rows from 60000-th row of original data.
# Progress saved: Translated 5830 rows from 60000-th row of original data.
# Progress saved: Translated 5840 rows from 60000-th row of original data.
# Progress saved: Translated 5850 rows from 60000-th row of original data.
# Progress saved: Translated 5860 rows from 60000-th row of original data.
# Progress saved: Translated 5870 rows from 60000-th row of original data.
# Progress saved: Translated 5880 rows from 60000-th row of original data.
# Progress saved: Translated 5890 rows from 60000-th row of original data.
# Progress saved: Translated 5900 rows from 60000-th row of original data.
# Progress saved: Translated 5910 rows from 60000-th row of original data.
# Progress saved: Translated 5920 rows from 60000-th row of original data.
# Progress saved: Translated 5930 rows from 60000-th row of original data.
# Progress saved: Translated 5940 rows from 60000-th row of original data.
# Progress saved: Translated 5950 rows from 60000-th row of original data.
# Progress saved: Translated 5960 rows from 60000-th row of original data.
# Progress saved: Translated 5970 rows from 60000-th row of original data.
# Progress saved: Translated 5980 rows from 60000-th row of original data.
# Progress saved: Translated 5990 rows from 60000-th row of original data.
# Progress saved: Translated 6000 rows from 60000-th row of original data.
# Progress saved: Translated 6010 rows from 60000-th row of original data.
# Progress saved: Translated 6020 rows from 60000-th row of original data.
# Progress saved: Translated 6030 rows from 60000-th row of original data.
# Progress saved: Translated 6040 rows from 60000-th row of original data.
# Progress saved: Translated 6050 rows from 60000-th row of original data.
# Progress saved: Translated 6060 rows from 60000-th row of original data.
# Progress saved: Translated 6070 rows from 60000-th row of original data.
# Progress saved: Translated 6080 rows from 60000-th row of original data.
# Progress saved: Translated 6090 rows from 60000-th row of original data.
# Progress saved: Translated 6100 rows from 60000-th row of original data.
# Progress saved: Translated 6110 rows from 60000-th row of original data.
# Progress saved: Translated 6120 rows from 60000-th row of original data.
# Progress saved: Translated 6130 rows from 60000-th row of original data.
# Progress saved: Translated 6140 rows from 60000-th row of original data.
# Progress saved: Translated 6150 rows from 60000-th row of original data.
# Progress saved: Translated 6160 rows from 60000-th row of original data.
# Progress saved: Translated 6170 rows from 60000-th row of original data.
# Progress saved: Translated 6180 rows from 60000-th row of original data.
# Progress saved: Translated 6190 rows from 60000-th row of original data.
# Progress saved: Translated 6200 rows from 60000-th row of original data.
# Progress saved: Translated 6210 rows from 60000-th row of original data.
# Progress saved: Translated 6220 rows from 60000-th row of original data.
# Progress saved: Translated 6230 rows from 60000-th row of original data.
# Progress saved: Translated 6240 rows from 60000-th row of original data.
# Progress saved: Translated 6250 rows from 60000-th row of original data.
# Progress saved: Translated 6260 rows from 60000-th row of original data.
# Progress saved: Translated 6270 rows from 60000-th row of original data.
# Progress saved: Translated 6280 rows from 60000-th row of original data.
# Progress saved: Translated 6290 rows from 60000-th row of original data.
# Progress saved: Translated 6300 rows from 60000-th row of original data.
# Progress saved: Translated 6310 rows from 60000-th row of original data.
# Progress saved: Translated 6320 rows from 60000-th row of original data.
# Progress saved: Translated 6330 rows from 60000-th row of original data.
# Progress saved: Translated 6340 rows from 60000-th row of original data.
# Progress saved: Translated 6350 rows from 60000-th row of original data.
# Progress saved: Translated 6360 rows from 60000-th row of original data.
# Progress saved: Translated 6370 rows from 60000-th row of original data.
# Progress saved: Translated 6380 rows from 60000-th row of original data.
# Progress saved: Translated 6390 rows from 60000-th row of original data.
# Progress saved: Translated 6400 rows from 60000-th row of original data.
# Progress saved: Translated 6410 rows from 60000-th row of original data.
# Progress saved: Translated 6420 rows from 60000-th row of original data.
# Progress saved: Translated 6430 rows from 60000-th row of original data.
# Progress saved: Translated 6440 rows from 60000-th row of original data.
# Progress saved: Translated 6450 rows from 60000-th row of original data.
# Progress saved: Translated 6460 rows from 60000-th row of original data.
# Progress saved: Translated 6470 rows from 60000-th row of original data.
# Progress saved: Translated 6480 rows from 60000-th row of original data.
# Progress saved: Translated 6490 rows from 60000-th row of original data.
# Progress saved: Translated 6500 rows from 60000-th row of original data.
# Progress saved: Translated 6510 rows from 60000-th row of original data.
# Progress saved: Translated 6520 rows from 60000-th row of original data.
# Progress saved: Translated 6530 rows from 60000-th row of original data.
# Progress saved: Translated 6540 rows from 60000-th row of original data.
# Progress saved: Translated 6550 rows from 60000-th row of original data.
# Progress saved: Translated 6560 rows from 60000-th row of original data.
# Progress saved: Translated 6570 rows from 60000-th row of original data.
# Progress saved: Translated 6580 rows from 60000-th row of original data.
# Progress saved: Translated 6590 rows from 60000-th row of original data.
# ...
# Rate limit reached. Stopping translation. Last text: i feel i ought to sit on the naughty step with all the fabric i have been buying
# Rate limit reached. Stopping translation. Last text: i had bought some ice cream to eat but i didnt eat it since i was feeling all virtuous
# Rate limit reached. Stopping translation. Last text: im feeling rather cute if i do say so myselfRate limit reached. Stopping translation. Last text: i was too occupied feeling triumphant
#
# Rate limit reached. Stopping translation. Last text: i always feel so stupid do you know that i really really really really really really really really really really really wanna talk to him because i miss him so much
# Rate limit reached. Stopping translation. Last text: i feel no need to be assured whether there is some god or not
# Rate limit reached. Stopping translation. Last text: i told her feeling disappointed that i was still incarcerated
# Rate limit reached. Stopping translation. Last text: i couldn t help but feeling a little perverse kind of like wanking in a church except the priest wasn t joining in and making the choir boys watch
# Rate limit reached. Stopping translation. Last text: i t feel rejected nd unsure f myselfRate limit reached. Stopping translation. Last text: i couldnt help but feel shy different and surprisingly she also felt the same
#
# Rate limit reached. Stopping translation. Last text: i think it goes without saying that don was feeling a bit lonely but did that mean that he truly was in fact alone
# Rate limit reached. Stopping translation. Last text: i feel like its more ok or rather im more ok now than i was when i thought i was miscarrying at the startRate limit reached. Stopping translation. Last text: i thought her beautiful radiant was the word and that is how i feel today reading these two reviews of dangerous neighbors
#
# Rate limit reached. Stopping translation. Last text: i feel like these are a few but vital reasons that are keeping it from being great
# Rate limit reached. Stopping translation. Last text: i feel like loneliness and sorrow envelope my tortured heart
# Rate limit reached. Stopping translation. Last text: i didn t get handed the check i started doubting i started feeling rejected
# Rate limit reached. Stopping translation. Last text: i do whatever it takes to help my clients feel amazing
# Rate limit reached. Stopping translation. Last text: i find him incredibly cute and i feel really bad for the little guy
# Rate limit reached. Stopping translation. Last text: i feel so selfish but thinking and knowing about it makes me even more selfish to me
# Rate limit reached. Stopping translation. Last text: i now stick to a paleo diet and i feel amazing
# Rate limit reached. Stopping translation. Last text: i feel confident i can go back to my internal medicine physician with a new game plan
# Rate limit reached. Stopping translation. Last text: im starting to feel slightly overwhelmed
# Rate limit reached. Stopping translation. Last text: i woke up i started thinking about feeling humiliated and realized that i only feel such a way in dreams
# Rate limit reached. Stopping translation. Last text: i feel is not acceptable as the deer blends into the background
# Rate limit reached. Stopping translation. Last text: i was feeling anxious i d lose the thought in my head and we know what s in my head is worth hearing and so instead of making time for your thoughts you d been considering and crafting through the whole conversation i blurted out mine
# Rate limit reached. Stopping translation. Last text: i know alot of info you dont really need but i feel its vital to my story
# Rate limit reached. Stopping translation. Last text: i actually am feeling not so despairing about the situation with him
# Rate limit reached. Stopping translation. Last text: i was still sitting kneeling on the bed my legs started feeling kind of shaky during these intense pressure waves
# Rate limit reached. Stopping translation. Last text: i feel irritated with my kidsRate limit reached. Stopping translation. Last text: i feel more inhibited at my sewing machine than i did as a teenager without a sewing machine or any idea of how to construct clothes but back then i reconstructed countless shirts made belts fashioned skirts out of yarn
#
# Rate limit reached. Stopping translation. Last text: i hope im not jinxing myself by feeling so jubilant
# Rate limit reached. Stopping translation. Last text: i get the feeling he is a lovely guy and im very happy to see him do so well at atletico
# Rate limit reached. Stopping translation. Last text: i like amsterdam so far and the people has made me feel welcomed
# Rate limit reached. Stopping translation. Last text: i feel a gentle reminder that im not fighting these battles in my strength
# Rate limit reached. Stopping translation. Last text: i feel miserable this morning
# Rate limit reached. Stopping translation. Last text: i feel scared as of when he try to ask about we relationship i try to divert at other topic
# Rate limit reached. Stopping translation. Last text: i feel our connection with football is a very ugly and brutal state of affairs where we do not know who to trust
# Rate limit reached. Stopping translation. Last text: i feel physically and how drained mentally running is still fun
# Rate limit reached. Stopping translation. Last text: i started feeling cold in my wet jacket
# Rate limit reached. Stopping translation. Last text: i don t think there s ever been a time in my life that i feel more passionate about this topic
# Rate limit reached. Stopping translation. Last text: i feel dirty watching this
# Rate limit reached. Stopping translation. Last text: i feel truly blessed to have so many wonderful people in my life
# Rate limit reached. Stopping translation. Last text: i feel as though animals are in many ways superior to us human beings
# Rate limit reached. Stopping translation. Last text: i secretly relish feeling pathetic and i love any moment that reminds me i am alive and fragile
# Rate limit reached. Stopping translation. Last text: i couldnt even paint the willow tree in dustins room with brooke without feeling resentful
# Rate limit reached. Stopping translation. Last text: i feeling anxious
# Rate limit reached. Stopping translation. Last text: i bought a whole lot of stuff i feel like it took me forever and my feet were super sore by the end
# Rate limit reached. Stopping translation. Last text: i feel like i can t really plan anything else until this is resolved
# Rate limit reached. Stopping translation. Last text: i feel damaged somehow
# Rate limit reached. Stopping translation. Last text: i ain t happy but i m feeling glad i got sunshine in a bag i m useless but not for long the future is coming on
# Rate limit reached. Stopping translation. Last text: i feel furious at the havoc shes wrecked and that shes sitting on her ass still feeling sorry for herself
# Rate limit reached. Stopping translation. Last text: i feel like its making me some kinda helpless woman who has to let her husband drive for her
# Rate limit reached. Stopping translation. Last text: i actually feel somewhat disappointed
# Rate limit reached. Stopping translation. Last text: i feel so virtuous for finishing something i should have done last month
# Rate limit reached. Stopping translation. Last text: i don t want you to feel pressured or obligated
# Rate limit reached. Stopping translation. Last text: i am really happy because i am feeling so joyful even though i have a long way to go
# Rate limit reached. Stopping translation. Last text: i was feeling pretty defeated about not running the half marathon and just didnt feel like writing about it
# Rate limit reached. Stopping translation. Last text: i want to actively feel awkward and make mistakes all the time
# Rate limit reached. Stopping translation. Last text: ill be out a few times on the bike before then and although im feeling a little out of practice the firetower trails at lochgilphead were fantastic fun and i surprised myself a little with my downhill riding
# Rate limit reached. Stopping translation. Last text: i feel she means it in a pleasant way
# Rate limit reached. Stopping translation. Last text: i learned from that experience is that when i feel that way as though being truthful is wrong that i need to cater to a persons emotions out of fear for the fallout or the consequences there is something very wrong going on
# Rate limit reached. Stopping translation. Last text: i am towards sadness these days i still feel sentimental upon sassys departure back to her old home
# Rate limit reached. Stopping translation. Last text: i am not late by all means but i feel that the last unprotected sex took place when i could be ovulating
# Rate limit reached. Stopping translation. Last text: i feel fearful this week
# Rate limit reached. Stopping translation. Last text: i am not really sure how this came about but ive been feeling a lot more compassionate and forgiving lately
# Rate limit reached. Stopping translation. Last text: i love the feel of having my flesh tortured
# Rate limit reached. Stopping translation. Last text: i feel i have been wronged i feel angry and my pride keeps the grudge hot on my shoulders
# Rate limit reached. Stopping translation. Last text: i was listening to the song lovers eyes it hit me that through the course of the song it goes from a somber almost depressingly dark tone to a hopeful redemptive feeling chorus of passionate lyrics
# Rate limit reached. Stopping translation. Last text: i am still feeling very tender after my day at nec on sunday so havent managed to get any crafting done so far this week hhhhmmmmpphhhhh must sort that out got tons to do anyway over at a href http paper craftingjourney
# Rate limit reached. Stopping translation. Last text: im alone feeling doubtful and feeling incapable of understanding what is happening in my life
# Rate limit reached. Stopping translation. Last text: i went for a walk in the park feeling quite taken with this charming anything to gratitude
# Rate limit reached. Stopping translation. Last text: i often feel ashamed
# Rate limit reached. Stopping translation. Last text: i know i shouldnt be feeling this way i know i must be brave and i know i can do it
# Rate limit reached. Stopping translation. Last text: i wasn t feeling too friendly so i ignored their pathetic attempts to make nice with me
# Rate limit reached. Stopping translation. Last text: i feel like i shouldnt be showing like this considering i have lost weight
# Rate limit reached. Stopping translation. Last text: i feel so jaded all the time
# Rate limit reached. Stopping translation. Last text: i always feel so helpless during times of disaster but i feel a little better knowing that even a few dollars can make a difference for someone in need
# Rate limit reached. Stopping translation. Last text: i fear that i am doomed to feel suffering from the past
# Rate limit reached. Stopping translation. Last text: i instead enjoyed the night but still feeling that i was so gorgeous and sexy
# Rate limit reached. Stopping translation. Last text: i can go and enjoy a little something out of doors without being made to feel at like some kind of tragic combination of heroic addict and infidel
# Rate limit reached. Stopping translation. Last text: i was feeling a bit better but ended up being about a second slower than i would have liked
# Rate limit reached. Stopping translation. Last text: im back on track and no longer feeling like this cycle is doomed
# Rate limit reached. Stopping translation. Last text: im feeling super proud of myself at the news
# Rate limit reached. Stopping translation. Last text: i know this is one of those one sided arguments but its out i feel and since this is petty complaint night
# Rate limit reached. Stopping translation. Last text: i feel that ive become too complacent in this life im leading at the moment
# Rate limit reached. Stopping translation. Last text: im very sad lonely feel ugly when i feel out of control
# Rate limit reached. Stopping translation. Last text: im feeling listless and dull all because something i didnt want to happen wont happen
# Rate limit reached. Stopping translation. Last text: i slept in too much to make the am class but i made it in for the am class a little nervous but feeling very stubborn
# Rate limit reached. Stopping translation. Last text: i am going to be completely honest so that i can sort out through all of these feelings and issues to become once again the gorgeous carefree happy person i used to be in what feels like another lifetime
# Rate limit reached. Stopping translation. Last text: just arrived in the university
# Rate limit reached. Stopping translation. Last text: i tend to stay healthier during cold season than my non running friends and i feel proud of my health at
# Rate limit reached. Stopping translation. Last text: i also feel somehow gloomy because this might be my first step into another life
# Rate limit reached. Stopping translation. Last text: i think i feel equally as terrified although also inspired by the belief that there exists vaster and grander vistas than my mind can comprehend celestial vistas if you ignore the cliches of that term
# Rate limit reached. Stopping translation. Last text: i feel peaceful for the first time since weeks
# Rate limit reached. Stopping translation. Last text: im feeling casual and often reach for whats closest
# Rate limit reached. Stopping translation. Last text: i feel like there s a lot of heart people are so compassionate
# Rate limit reached. Stopping translation. Last text: i got a feeling i ll be a really grumpy mother constantly worrying about the finances
# Rate limit reached. Stopping translation. Last text: i feel more at cause and self determined than i have in years
# Rate limit reached. Stopping translation. Last text: i realize it is only may and several weeks remain in the prime time job hunt but i am feeling defeated and as if i will not be able to locate a band job
# Rate limit reached. Stopping translation. Last text: i can t really complain but there are times when i just don t feel like the brave little monkey that i know i am inside
# Rate limit reached. Stopping translation. Last text: i think this pretty much speaks for itself of why i am feeling pretty grouchy
# Rate limit reached. Stopping translation. Last text: i feel vain typing my thoughts out its just such a little excuse to take a break from studying
# Rate limit reached. Stopping translation. Last text: i was uneasy with this feeling but now ive just accepted it
# Rate limit reached. Stopping translation. Last text: i have to get my labs checked again on friday and if i am still feeling crappy and my hgb is any lower they will transfuse me
# Rate limit reached. Stopping translation. Last text: i am feeling very unsure that this is the route that we should have gone
# Rate limit reached. Stopping translation. Last text: i got bad lucks i miss some concerts feeling like friends are abandoning me assignments are fucking piling got critics every meeting feeling like a dumb ass donkey
# Rate limit reached. Stopping translation. Last text: i feel somewhat more energetic but man my body is hanging onto every single gram of fat it can
# Rate limit reached. Stopping translation. Last text: i must admit the last couple of days has felt like a month i feel jaded and vulnerable
# Rate limit reached. Stopping translation. Last text: i don t feel humiliated
# Rate limit reached. Stopping translation. Last text: i can think of a couple i feel there s a longing in certain groups of fans when i meet them for the story to be finished because we really left it up in the air and i feel a bit badly about that because i was part of that decision making process
# Rate limit reached. Stopping translation. Last text: i feel dirty dirty dirty
# Rate limit reached. Stopping translation. Last text: i have a month old daughter and to be honest i beat myself up everyday about it because i feel like a horrible mother at times
# Translation process stopped due to rate limit.
# Final translation saved.
